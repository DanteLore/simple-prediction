# %% [markdown]
# # Pull the data from Athena and turn it into training data
#
# TODO:
#
# * ~~More than one site~~
# * ~~Deal with nulls~~
# * Deal with missing data by selecting against the datetime, not relying on a row being there for the measurement
# * ~~Better windowing~~
# * Other data as inputs (pressure, wind speed etc)
# * Encode time as input (e.g. hour of day)
# * Wind speed and direction as vector (snazzy!)
# * ~~Longer input history~~
# * ~~More sites in input~~
# * ~~Normalise the data (temp => -1 - 1 etc)~~
# * Play around with configurable input and output size - e.g. predict the next 24h with 24 outputs

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from pyathena import connect
from pyathena.pandas.cursor import PandasCursor
from sklearn.model_selection import train_test_split
from numpy.lib.stride_tricks import sliding_window_view

cursor = connect(s3_staging_dir="s3://dantelore.queryresults/pyathena/",
                 region_name="eu-west-1", cursor_class=PandasCursor).cursor()

length = 24
csv_data_cache_filename = "data/weather_models/raw_data.csv"

# Load the data from disk or Athena
if Path(csv_data_cache_filename).is_file():
    print("Loading weather data from cache")
    df = pd.read_csv(csv_data_cache_filename)
else:
    df = cursor.execute("select site_name, observation_ts, temperature from lake.weather order by site_name, observation_ts").as_pandas()
    df.to_csv(csv_data_cache_filename, index=False)

# Replace NaN's with 0 - which will confuse the network a little, but will preserve the time element of the input
df['temperature'].fillna({'temperature': 0.0}, inplace=True)

# Convert all the numbers to float32 for tensorflow
df['temperature'] = df['temperature'].astype('float32')

# Calculate the offset and scale for normalising the data
offset = df['temperature'].mean()
scale = df['temperature'].std()
print(f"Offset (mean temp): {offset}, Scale (stdev temp): {scale}")

# Normalise the data
df['temperature'] = df['temperature'].apply(lambda x: (x - offset) / scale)     

input_sequences = np.empty([0, 24])
# Window the data
for site_name, readings in df.groupby('site_name'):
    temps = readings['temperature'].to_numpy()

    windows = sliding_window_view(temps, 24)

    input_sequences = np.append(windows, input_sequences, axis=0)

    print(f"Window shape site {site_name}: {windows.shape}")

print(f"Combined data shape: {input_sequences.shape}")

# Wrap up the individual readings into a single 'timestep' for the RNN.  Add pressure, TOD etc to this bag later if you want
input_sequences = np.array([[[y] for y in x] for x in input_sequences])

print(f"All data shape when wrapped: {input_sequences.shape}")

# Some funky numpy slicing here.  We are slicing by axis in a 3D array - so xs takes all but the last item on the 2nd axis, ys takes only the last
xs = input_sequences[:,:-1]
ys = input_sequences[:,-1]

x_train, x_test, y_train, y_test = train_test_split(xs, ys, test_size=0.05)
#x_train = xs[0:8000]
#x_test = xs[8000:]
#y_train = ys[0:8000]
#y_test = ys[8000:]

# ((?, 23, 1), (?, 1), (?, 23, 1), (?, 1))
print(f"x_train: {x_train.shape} y_train: {y_train.shape} x_test: {x_test.shape} y_test: {y_test.shape}")
# Out:
# Loading weather data from cache
# Offset (mean temp): 10.089849472045898, Scale (stdev temp): 5.680954933166504
# Window shape site ABERDARON: (8820, 24)
# Window shape site ABERDEEN AIRPORT: (9040, 24)
# Window shape site ABERPORTH: (9524, 24)
# Window shape site ABOYNE: (9464, 24)
# Window shape site ALBEMARLE: (9492, 24)
# Window shape site ALTNAHARRA SAWS: (9435, 24)
# Window shape site ANDREWSFIELD: (9399, 24)
# Window shape site AONACH MOR SUMMIT: (5290, 24)
# Window shape site AULTBEA: (9519, 24)
# Window shape site AVIEMORE: (9434, 24)
# Window shape site BALLYPATRICK FOREST: (9526, 24)
# Window shape site BALTASOUND: (9455, 24)
# Window shape site BEALACH NA BA: (8539, 24)
# Window shape site BEDFORD: (9526, 24)
# Window shape site BELFAST INTERNATIONAL AIRPORT: (9550, 24)
# Window shape site BELMULLET: (9557, 24)
# Window shape site BENSON: (9318, 24)
# Window shape site BINGLEY SAMOS: (9525, 24)
# Window shape site BOSCOMBE DOWN: (9533, 24)
# Window shape site BOULMER: (9072, 24)
# Window shape site BOURNEMOUTH AIRPORT: (9267, 24)
# Window shape site BRIDLINGTON MRSC: (9541, 24)
# Window shape site BRIZE NORTON: (9534, 24)
# Window shape site CAIRN GORM SUMMIT: (4030, 24)
# Window shape site CAIRNWELL: (6671, 24)
# Window shape site CAMBORNE: (9566, 24)
# Window shape site CAMPBELTOWN AIRPORT: (8883, 24)
# Window shape site CAPEL CURIG: (9485, 24)
# Window shape site CARDINHAM: (9544, 24)
# Window shape site CARLISLE: (9418, 24)
# Window shape site CASTLEDERG: (9437, 24)
# Window shape site CHARLWOOD: (9458, 24)
# Window shape site CHARTERHALL: (7615, 24)
# Window shape site CHIVENOR: (9500, 24)
# Window shape site CHURCH LAWFORD: (9523, 24)
# Window shape site COLESHILL: (9521, 24)
# Window shape site CONINGSBY: (9544, 24)
# Window shape site CRANWELL: (9413, 24)
# Window shape site CREDENHILL: (8806, 24)
# Window shape site CROSBY: (9502, 24)
# Window shape site CULDROSE: (9557, 24)
# Window shape site DONNA NOOK: (9311, 24)
# Window shape site DRUMALBIN: (9468, 24)
# Window shape site DUNDRENNAN: (9543, 24)
# Window shape site DUNKESWELL AERODROME: (9359, 24)
# Window shape site EDINBURGH/GOGARBANK: (9427, 24)
# Window shape site ESKDALEMUIR: (9463, 24)
# Window shape site EXETER AIRPORT: (9503, 24)
# Window shape site FAIR ISLE: (9307, 24)
# Window shape site FARNBOROUGH: (5030, 24)
# Window shape site FYLINGDALES: (9520, 24)
# Window shape site GLASGOW/BISHOPTON: (9483, 24)
# Window shape site GLEN OGLE: (1396, 24)
# Window shape site GLENANNE: (9518, 24)
# Window shape site GREAT DUN FELL 2: (9282, 24)
# Window shape site GUERNSEY: (9496, 24)
# Window shape site HAWARDEN: (9490, 24)
# Window shape site HEATHROW: (9557, 24)
# Window shape site HEREFORD: (688, 24)
# Window shape site HERSTMONCEUX WEST END: (9520, 24)
# Window shape site HIGH WYCOMBE: (688, 24)
# Window shape site HOLBEACH: (9347, 24)
# Window shape site INVERBERVIE: (9538, 24)
# Window shape site ISLAY AIRPORT: (9330, 24)
# Window shape site ISLE OF PORTLAND: (9541, 24)
# Window shape site JERSEY: (9561, 24)
# Window shape site KENLEY: (9400, 24)
# Window shape site KESWICK: (9424, 24)
# Window shape site KINLOSS: (9508, 24)
# Window shape site KIRKWALL: (688, 24)
# Window shape site KIRKWALL AIRPORT: (8802, 24)
# Window shape site LAKE VYRNWY SAWS: (9538, 24)
# Window shape site LANGDON BAY: (9510, 24)
# Window shape site LARKHILL: (9502, 24)
# Window shape site LECONFIELD SAR: (9525, 24)
# Window shape site LEEK: (688, 24)
# Window shape site LEEMING: (9529, 24)
# Window shape site LERWICK (S. SCREEN): (9507, 24)
# Window shape site LEUCHARS: (9327, 24)
# Window shape site LISCOMBE: (9215, 24)
# Window shape site LITTLE RISSINGTON (ESAWS): (9527, 24)
# Window shape site LOCH GLASCARNOCH: (9439, 24)
# Window shape site LOFTUS (SAMOS): (9540, 24)
# Window shape site LOSSIEMOUTH: (9510, 24)
# Window shape site LOUGH FEA: (9392, 24)
# Window shape site LYNEHAM: (9528, 24)
# Window shape site MAGILLIGAN: (9455, 24)
# Window shape site MALIN HEAD: (9549, 24)
# Window shape site MANSTON: (8031, 24)
# Window shape site MARHAM: (9479, 24)
# Window shape site MIDDLE WALLOP: (9537, 24)
# Window shape site MILFORD HAVEN C.B.: (9512, 24)
# Window shape site MOUNT BATTEN: (9506, 24)
# Window shape site MUMBLES HEAD: (9505, 24)
# Window shape site NORTH WYKE: (9454, 24)
# Window shape site NORTHOLT: (9515, 24)
# Window shape site ODIHAM: (9542, 24)
# Window shape site PEMBREY SANDS: (9361, 24)
# Window shape site PERSHORE: (685, 24)
# Window shape site PRESTWICK RNAS: (9476, 24)
# Window shape site RAF HIGH WYCOMBE: (6252, 24)
# Window shape site REDESDALE CAMP: (9458, 24)
# Window shape site RHYL: (9550, 24)
# Window shape site ROCHES POINT: (9556, 24)
# Window shape site RONALDSWAY: (9571, 24)
# Window shape site ROSTHERNE NO 2: (9126, 24)
# Window shape site ROTHAMSTED: (9486, 24)
# Window shape site SCAMPTON: (7706, 24)
# Window shape site SCARBOROUGH: (9486, 24)
# Window shape site SCILLY ST MARYS: (9529, 24)
# Window shape site SENNYBRIDGE: (9420, 24)
# Window shape site SHAP: (9408, 24)
# Window shape site SHAWBURY: (9465, 24)
# Window shape site SHOBDON SAWS: (9463, 24)
# Window shape site SHOEBURYNESS: (9503, 24)
# Window shape site SHOREHAM: (9543, 24)
# Window shape site SOUTH UIST RANGE: (9489, 24)
# Window shape site SPADEADAM: (7806, 24)
# Window shape site ST CATHERINES PT.: (9459, 24)
# Window shape site ST-ATHAN: (9435, 24)
# Window shape site ST. BEES HEAD: (9511, 24)
# Window shape site STONYHURST: (9519, 24)
# Window shape site STORNOWAY: (688, 24)
# Window shape site STORNOWAY AIRPORT: (8803, 24)
# Window shape site STRATHALLAN: (9450, 24)
# Window shape site THORNECLIFFE LEEK: (8822, 24)
# Window shape site THORNEY ISLAND: (8987, 24)
# Window shape site THROCKMORTON: (8754, 24)
# Window shape site TIREE: (9533, 24)
# Window shape site TOPCLIFFE: (9447, 24)
# Window shape site TRAWSGOED: (9412, 24)
# Window shape site TULLOCH BRIDGE: (9166, 24)
# Window shape site VALENTIA OBSERVATORY: (9558, 24)
# Window shape site VALLEY: (9536, 24)
# Window shape site WADDINGTON: (9569, 24)
# Window shape site WAINFLEET: (9532, 24)
# Window shape site WALNEY ISLAND: (9518, 24)
# Window shape site WARCOP: (9469, 24)
# Window shape site WATNALL: (9535, 24)
# Window shape site WATTISHAM: (9562, 24)
# Window shape site WEST FREUGH: (8480, 24)
# Window shape site WEYBOURNE: (9530, 24)
# Window shape site WICK JOHN O GROATS AIRPORT: (9168, 24)
# Window shape site WITTERING: (9373, 24)
# Window shape site WOBURN: (9301, 24)
# Window shape site YEOVILTON: (9504, 24)
# Combined data shape: (1287343, 24)
# All data shape when wrapped: (1287343, 24, 1)
# x_train: (1222975, 23, 1) y_train: (1222975, 1) x_test: (64368, 23, 1) y_test: (64368, 1)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Bidirectional, LSTM, InputLayer
from tensorflow.keras.optimizers import Adam

model = Sequential([
    InputLayer((length - 1, 1)), # Input shape here - time steps, features.  We have length-1 steps here, each with 1 feature
    LSTM(64),
    Dense(units=8, activation='relu'),
    Dense(units=1, activation='linear')
])

adam = Adam(lr=0.0001)

model.compile(loss=tf.keras.losses.MeanSquaredError(), optimizer=adam, metrics=[tf.keras.metrics.MeanAbsoluteError()])

# Create the training history dataframe at the same time as the model...
history_df = pd.DataFrame(columns=['loss', 'mean_absolute_error', 'val_loss', 'val_mean_absolute_error'])

model.summary()
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
# 2023-01-26 15:47:02.188953: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-26 15:47:02.189090: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense (Dense)               (None, 8)                 520
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 17,425
# Trainable params: 17,425
# Non-trainable params: 0
# _________________________________________________________________
# /Users/dan/Development/simple-prediction/.venv/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
from datetime import datetime
import matplotlib.pyplot as plt
from IPython.display import clear_output
from tensorflow.keras.callbacks import ModelCheckpoint


tf.get_logger().setLevel('ERROR')

run_count = 1
epochs_per_run = 10
model_filename = 'data/weather_models/model1/'

cp = ModelCheckpoint(model_filename, save_best_only=True, verbose=0)

for run in range(0, run_count):
    print(f"Starting Run {run}/{run_count}")
    # Use verbose=2 here to prevent progreess bars locking up jupyter after a few hours
    history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=epochs_per_run, verbose=2, callbacks=[cp])

    history_df = pd.concat([history_df, pd.DataFrame(history.history)], ignore_index=True)

    plt.plot(history_df['mean_absolute_error'], label="Training Error")
    plt.plot(history_df['val_mean_absolute_error'], label="Validation Error")
    plt.title(f'Model Training Progress - Run {run} of {run_count}')
    plt.ylabel('Mean Absolute Error')
    plt.xlabel('Epoch')
    plt.show()
# Out:
# Starting Run 0/1
# 2023-01-26 15:47:02.687843: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-01-26 15:47:03.379999: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-01-26 15:47:03.546325: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-01-26 15:47:03.722654: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-01-26 15:55:04.865768: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-01-26 15:55:04.937151: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 38218/38218 - 496s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan - 496s/epoch - 13ms/step

# %%
from tensorflow.keras.models import load_model

# model = load_model(model_filename)

train_predictions = model.predict(x_train).flatten()
train_results = pd.DataFrame(data={'Predicted': train_predictions, "Actual": y_train.flatten()})

train_results['Predicted'] = train_results['Predicted'].apply(lambda x: x * scale + offset)
train_results['Actual'] = train_results['Actual'].apply(lambda x: x * scale + offset)

plt.plot(train_results['Predicted'][0:100])
plt.plot(train_results['Actual'][0:100])
# Out:
#     9/38218 [..............................] - ETA: 4:11
# 2023-01-26 15:55:19.491226: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2023-01-26 15:55:19.548584: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 38218/38218 [==============================] - 218s 6ms/step

# %%
val_predictions = model.predict(x_test).flatten()
val_results = pd.DataFrame(data={'Predicted': val_predictions, "Actual": y_test.flatten()})

val_results['Predicted'] = val_results['Predicted'].apply(lambda x: x * scale + offset)
val_results['Actual'] = val_results['Actual'].apply(lambda x: x * scale + offset)

plt.plot(val_results['Predicted'][0:100])
plt.plot(val_results['Actual'][0:100])
# Out:
# 2012/2012 [==============================] - 12s 6ms/step
