# %% [markdown]
# # Setup
#
# Download your Kaggle API key file to `kaggle.json` to allow download of the data (log in to Kaggle, go to profile -> account).
#
# See this guide for installing tensorflow on Apple silicon (e.g. my M1 laptop!): https://developer.apple.com/metal/tensorflow-plugin/
#
# For me though, I had to install specific versions:
# ```bash
# pip install tensorflow-macos==2.9
# pip install tensorflow-metal==0.5.0
# ```

# %%
import opendatasets as od
import pandas as pd
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Download the data

# %%
od.download("https://www.kaggle.com/datasets/ahsan81/hotel-reservations-classification-dataset", data_dir="data")

hotel_data = pd.read_csv("./data/hotel-reservations-classification-dataset/Hotel Reservations.csv")

hotel_data.head()
# Out:
# Skipping, found downloaded files in "data/hotel-reservations-classification-dataset" (use force=True to force download)
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# 1        Room_Type 1          5          2018             11             6
# 2        Room_Type 1          1          2018              2            28
# 3        Room_Type 1        211          2018              5            20
# 4        Room_Type 1         48          2018              4            11
#
#   market_segment_type  repeated_guest  no_of_previous_cancellations  \
# 0             Offline               0                             0
# 1              Online               0                             0
# 2              Online               0                             0
# 3              Online               0                             0
# 4              Online               0                             0
#
#    no_of_previous_bookings_not_canceled  avg_price_per_room  \
# 0                                     0               65.00
# 1                                     0              106.68
# 2                                     0               60.00
# 3                                     0              100.00
# 4                                     0               94.50
#
#    no_of_special_requests booking_status
# 0                       0   Not_Canceled
# 1                       1   Not_Canceled
# 2                       0       Canceled
# 3                       0       Canceled
# 4                       0       Canceled

# %%
hotel_data.describe()
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# count  36275.000000    36275.000000          36275.000000       36275.000000
# mean       1.844962        0.105279              0.810724           2.204300
# std        0.518715        0.402648              0.870644           1.410905
# min        0.000000        0.000000              0.000000           0.000000
# 25%        2.000000        0.000000              0.000000           1.000000
# 50%        2.000000        0.000000              1.000000           2.000000
# 75%        2.000000        0.000000              2.000000           3.000000
# max        4.000000       10.000000              7.000000          17.000000
#
#        required_car_parking_space     lead_time  arrival_year  arrival_month  \
# count                36275.000000  36275.000000  36275.000000   36275.000000
# mean                     0.030986     85.232557   2017.820427       7.423653
# std                      0.173281     85.930817      0.383836       3.069894
# min                      0.000000      0.000000   2017.000000       1.000000
# 25%                      0.000000     17.000000   2018.000000       5.000000
# 50%                      0.000000     57.000000   2018.000000       8.000000
# 75%                      0.000000    126.000000   2018.000000      10.000000
# max                      1.000000    443.000000   2018.000000      12.000000
#
#        arrival_date  repeated_guest  no_of_previous_cancellations  \
# count  36275.000000    36275.000000                  36275.000000
# mean      15.596995        0.025637                      0.023349
# std        8.740447        0.158053                      0.368331
# min        1.000000        0.000000                      0.000000
# 25%        8.000000        0.000000                      0.000000
# 50%       16.000000        0.000000                      0.000000
# 75%       23.000000        0.000000                      0.000000
# max       31.000000        1.000000                     13.000000
#
#        no_of_previous_bookings_not_canceled  avg_price_per_room  \
# count                          36275.000000        36275.000000
# mean                               0.153411          103.423539
# std                                1.754171           35.089424
# min                                0.000000            0.000000
# 25%                                0.000000           80.300000
# 50%                                0.000000           99.450000
# 75%                                0.000000          120.000000
# max                               58.000000          540.000000
#
#        no_of_special_requests
# count            36275.000000
# mean                 0.619655
# std                  0.786236
# min                  0.000000
# 25%                  0.000000
# 50%                  0.000000
# 75%                  1.000000
# max                  5.000000

# %% [markdown]
# # Clean and structure the training and test data

# %%
# Drop the answers to create the input/feature data
x_df = hotel_data.drop(['Booking_ID', 'booking_status'], axis=1)

# Months and years are more like categorical data than numeric.  Convert to strings, then call 'get_dummies' to explode/pivot
x_df['arrival_month'] = [f"month_{x}" for x in x_df['arrival_month']]
x_df['arrival_year'] = [f"year_{x}" for x in x_df['arrival_year']]


# Converts catagorical columns into multiple boolean columns by value - which sames a lot of hassle!
x_df = pd.get_dummies(x_df)

# Convert everything else into a float
x_df = x_df.astype('float64')

# Create the output/target data
y_df = hotel_data['booking_status'].replace({"Not_Canceled": 0.0, "Canceled": 1.0})

# split into test and training sets
x_train, x_test, y_train, y_test = train_test_split(x_df, y_df, test_size=0.2)

x_train
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 13521           2.0             0.0                   2.0                5.0
# 2579            2.0             0.0                   0.0                3.0
# 14569           2.0             0.0                   0.0                4.0
# 25134           2.0             0.0                   1.0                1.0
# 23041           3.0             0.0                   0.0                2.0
# ...             ...             ...                   ...                ...
# 2629            2.0             0.0                   1.0                2.0
# 32214           1.0             0.0                   1.0                2.0
# 11620           1.0             0.0                   1.0                0.0
# 30931           2.0             0.0                   0.0                4.0
# 15962           2.0             0.0                   1.0                4.0
#
#        required_car_parking_space  lead_time  arrival_date  repeated_guest  \
# 13521                         0.0      138.0          14.0             0.0
# 2579                          0.0       34.0          25.0             0.0
# 14569                         0.0       28.0           4.0             0.0
# 25134                         0.0        7.0          21.0             0.0
# 23041                         0.0      100.0          16.0             0.0
# ...                           ...        ...           ...             ...
# 2629                          0.0        6.0          11.0             0.0
# 32214                         0.0      219.0           4.0             0.0
# 11620                         0.0        0.0           9.0             0.0
# 30931                         0.0      232.0          20.0             0.0
# 15962                         0.0      117.0          27.0             0.0
#
#        no_of_previous_cancellations  no_of_previous_bookings_not_canceled  \
# 13521                           0.0                                   0.0
# 2579                            0.0                                   0.0
# 14569                           0.0                                   0.0
# 25134                           0.0                                   0.0
# 23041                           0.0                                   0.0
# ...                             ...                                   ...
# 2629                            0.0                                   0.0
# 32214                           0.0                                   0.0
# 11620                           0.0                                   0.0
# 30931                           0.0                                   0.0
# 15962                           0.0                                   0.0
#
#        ...  arrival_month_month_5  arrival_month_month_6  \
# 13521  ...                    1.0                    0.0
# 2579   ...                    0.0                    0.0
# 14569  ...                    0.0                    0.0
# 25134  ...                    1.0                    0.0
# 23041  ...                    0.0                    0.0
# ...    ...                    ...                    ...
# 2629   ...                    0.0                    0.0
# 32214  ...                    0.0                    0.0
# 11620  ...                    0.0                    0.0
# 30931  ...                    0.0                    0.0
# 15962  ...                    0.0                    0.0
#
#        arrival_month_month_7  arrival_month_month_8  arrival_month_month_9  \
# 13521                    0.0                    0.0                    0.0
# 2579                     0.0                    0.0                    0.0
# 14569                    0.0                    0.0                    0.0
# 25134                    0.0                    0.0                    0.0
# 23041                    0.0                    1.0                    0.0
# ...                      ...                    ...                    ...
# 2629                     0.0                    0.0                    1.0
# 32214                    0.0                    0.0                    1.0
# 11620                    0.0                    0.0                    0.0
# 30931                    0.0                    0.0                    1.0
# 15962                    1.0                    0.0                    0.0
#
#        market_segment_type_Aviation  market_segment_type_Complementary  \
# 13521                           0.0                                0.0
# 2579                            0.0                                0.0
# 14569                           0.0                                0.0
# 25134                           0.0                                0.0
# 23041                           0.0                                0.0
# ...                             ...                                ...
# 2629                            0.0                                0.0
# 32214                           0.0                                0.0
# 11620                           0.0                                0.0
# 30931                           0.0                                0.0
# 15962                           0.0                                0.0
#
#        market_segment_type_Corporate  market_segment_type_Offline  \
# 13521                            0.0                          0.0
# 2579                             0.0                          0.0
# 14569                            0.0                          0.0
# 25134                            0.0                          1.0
# 23041                            0.0                          0.0
# ...                              ...                          ...
# 2629                             0.0                          0.0
# 32214                            0.0                          1.0
# 11620                            1.0                          0.0
# 30931                            0.0                          0.0
# 15962                            0.0                          1.0
#
#        market_segment_type_Online
# 13521                         1.0
# 2579                          1.0
# 14569                         1.0
# 25134                         0.0
# 23041                         1.0
# ...                           ...
# 2629                          1.0
# 32214                         0.0
# 11620                         0.0
# 30931                         1.0
# 15962                         0.0
#
# [29020 rows x 42 columns]

# %% [markdown]
# # Create the NN model

# %%
model = Sequential()
model.add(Dense(units=12, activation='sigmoid', input_dim=len(x_train.columns)))
#model.add(Dense(units=12, activation='sigmoid'))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(loss='mse', optimizer='sgd', metrics='accuracy')
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
# 2023-01-11 00:14:37.899243: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-01-11 00:14:37.899354: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# # Train the NN

# %%
model.fit(x_train, y_train, epochs=1000, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Epoch 1/1000
# 2023-01-11 00:14:38.011634: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-01-11 00:14:38.160607: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 904/907 [============================>.] - ETA: 0s - loss: 0.1991 - accuracy: 0.7115
# 2023-01-11 00:14:42.208595: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 907/907 [==============================] - 5s 5ms/step - loss: 0.1992 - accuracy: 0.7112 - val_loss: 0.1909 - val_accuracy: 0.7354
# Epoch 2/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1923 - accuracy: 0.7271 - val_loss: 0.1894 - val_accuracy: 0.7369
# Epoch 3/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1911 - accuracy: 0.7273 - val_loss: 0.1884 - val_accuracy: 0.7384
# Epoch 4/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1903 - accuracy: 0.7271 - val_loss: 0.1873 - val_accuracy: 0.7371
# Epoch 5/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1897 - accuracy: 0.7280 - val_loss: 0.1865 - val_accuracy: 0.7367
# Epoch 6/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1890 - accuracy: 0.7298 - val_loss: 0.1859 - val_accuracy: 0.7406
# Epoch 7/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1880 - accuracy: 0.7303 - val_loss: 0.1843 - val_accuracy: 0.7427
# Epoch 8/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1853 - accuracy: 0.7337 - val_loss: 0.1824 - val_accuracy: 0.7428
# Epoch 9/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1847 - accuracy: 0.7338 - val_loss: 0.1821 - val_accuracy: 0.7451
# Epoch 10/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1841 - accuracy: 0.7337 - val_loss: 0.1808 - val_accuracy: 0.7435
# Epoch 11/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1834 - accuracy: 0.7350 - val_loss: 0.1800 - val_accuracy: 0.7471
# Epoch 12/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1831 - accuracy: 0.7353 - val_loss: 0.1799 - val_accuracy: 0.7451
# Epoch 13/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1826 - accuracy: 0.7353 - val_loss: 0.1837 - val_accuracy: 0.7352
# Epoch 14/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1823 - accuracy: 0.7334 - val_loss: 0.1782 - val_accuracy: 0.7439
# Epoch 15/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1818 - accuracy: 0.7341 - val_loss: 0.1788 - val_accuracy: 0.7456
# Epoch 16/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1813 - accuracy: 0.7355 - val_loss: 0.1759 - val_accuracy: 0.7469
# Epoch 17/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1807 - accuracy: 0.7358 - val_loss: 0.1767 - val_accuracy: 0.7465
# Epoch 18/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1799 - accuracy: 0.7375 - val_loss: 0.1762 - val_accuracy: 0.7483
# Epoch 19/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1794 - accuracy: 0.7370 - val_loss: 0.1755 - val_accuracy: 0.7493
# Epoch 20/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1793 - accuracy: 0.7372 - val_loss: 0.1747 - val_accuracy: 0.7500
# Epoch 21/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1789 - accuracy: 0.7359 - val_loss: 0.1754 - val_accuracy: 0.7479
# Epoch 22/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1780 - accuracy: 0.7376 - val_loss: 0.1787 - val_accuracy: 0.7352
# Epoch 23/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1774 - accuracy: 0.7377 - val_loss: 0.1745 - val_accuracy: 0.7475
# Epoch 24/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1778 - accuracy: 0.7361 - val_loss: 0.1727 - val_accuracy: 0.7472
# Epoch 25/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1762 - accuracy: 0.7388 - val_loss: 0.1679 - val_accuracy: 0.7562
# Epoch 26/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1764 - accuracy: 0.7361 - val_loss: 0.1675 - val_accuracy: 0.7537
# Epoch 27/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1759 - accuracy: 0.7411 - val_loss: 0.1686 - val_accuracy: 0.7553
# Epoch 28/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1748 - accuracy: 0.7393 - val_loss: 0.1680 - val_accuracy: 0.7629
# Epoch 29/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1753 - accuracy: 0.7400 - val_loss: 0.1654 - val_accuracy: 0.7591
# Epoch 30/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1747 - accuracy: 0.7396 - val_loss: 0.1710 - val_accuracy: 0.7439
# Epoch 31/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1735 - accuracy: 0.7409 - val_loss: 0.1671 - val_accuracy: 0.7515
# Epoch 32/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1739 - accuracy: 0.7396 - val_loss: 0.1707 - val_accuracy: 0.7468
# Epoch 33/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1741 - accuracy: 0.7413 - val_loss: 0.1642 - val_accuracy: 0.7611
# Epoch 34/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1733 - accuracy: 0.7416 - val_loss: 0.1668 - val_accuracy: 0.7519
# Epoch 35/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1728 - accuracy: 0.7404 - val_loss: 0.1618 - val_accuracy: 0.7606
# Epoch 36/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1726 - accuracy: 0.7415 - val_loss: 0.1627 - val_accuracy: 0.7622
# Epoch 37/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1724 - accuracy: 0.7413 - val_loss: 0.1668 - val_accuracy: 0.7558
# Epoch 38/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1720 - accuracy: 0.7402 - val_loss: 0.1596 - val_accuracy: 0.7643
# Epoch 39/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1718 - accuracy: 0.7427 - val_loss: 0.1897 - val_accuracy: 0.6769
# Epoch 40/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1716 - accuracy: 0.7409 - val_loss: 0.1695 - val_accuracy: 0.7421
# Epoch 41/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1702 - accuracy: 0.7431 - val_loss: 0.1648 - val_accuracy: 0.7533
# Epoch 42/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1703 - accuracy: 0.7434 - val_loss: 0.1649 - val_accuracy: 0.7556
# Epoch 43/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1693 - accuracy: 0.7463 - val_loss: 0.1801 - val_accuracy: 0.7382
# Epoch 44/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1698 - accuracy: 0.7454 - val_loss: 0.1857 - val_accuracy: 0.6746
# Epoch 45/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1686 - accuracy: 0.7481 - val_loss: 0.1695 - val_accuracy: 0.7468
# Epoch 46/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1701 - accuracy: 0.7456 - val_loss: 0.1637 - val_accuracy: 0.7504
# Epoch 47/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1686 - accuracy: 0.7486 - val_loss: 0.1684 - val_accuracy: 0.7531
# Epoch 48/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1680 - accuracy: 0.7467 - val_loss: 0.1532 - val_accuracy: 0.7734
# Epoch 49/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1685 - accuracy: 0.7457 - val_loss: 0.1787 - val_accuracy: 0.7212
# Epoch 50/1000
# 907/907 [==============================] - 4s 5ms/step - loss: 0.1676 - accuracy: 0.7473 - val_loss: 0.1543 - val_accuracy: 0.7722
# Epoch 51/1000
# 533/907 [================>.............] - ETA: 1s - loss: 0.1647 - accuracy: 0.7527

# %%
y_hat = model.predict(x_test)
y_hat = [0.0 if x < 0.5 else 1.0 for x in y_hat]

accuracy_score(y_test, y_hat)
# Out:
# 103/227 [============>.................] - ETA: 0s
# 2023-01-11 00:11:24.814303: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 227/227 [==============================] - 0s 2ms/step
# 0.7834596829772571

# %%
pd.DataFrame({
    'predicted': y_hat,
    'actual': y_test
})
# Out:
#        predicted  actual
# 20733        0.0     0.0
# 9754         1.0     0.0
# 13141        0.0     0.0
# 4282         0.0     0.0
# 20709        0.0     0.0
# ...          ...     ...
# 501          0.0     0.0
# 164          0.0     0.0
# 768          0.0     0.0
# 25717        0.0     0.0
# 8451         0.0     0.0
#
# [7255 rows x 2 columns]
